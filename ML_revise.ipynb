# %%
# To Chaliye shuru krte h

# %% [markdown]
# *   Most of the things are in slides, apart from it that is important can be found here.
#
# *   Some can be on notebook too.

# %% [markdown]
# **Vector**:An 'n'x'1' matrix

# %% [markdown]
# **Feature Scaling:**
# * Help gradient decent work well
# * d

# %% [markdown]
# There are two methods of avoiding overfitting:
#
#
# 1.   Reduce no.of features.
# 2.   Regularisation
#
#
# **Regularisation**
# Using it simply reduces each parameter such that every parameter contribute less.

# %% [markdown]
# If you have classification problem, using linear regression isn't a good idea.

# %% [markdown]
# For logistic regression, sometimes gradient descent will converge to a local minimum (and fail to find the global minimum). This is **NOT** the reason we prefer more advanced optimization algorithms such as fminunc (conjugate gradient/BFGS/L-BFGS/etc).
#
# The reason we prefer most optimization algorithm because they are fast and do not require manual input of alpha.

# %% [markdown]
# **Questionaries:**
# 1. Model selection algorithm(later in the course).
# 2. How to decide hypothesis function.
